# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import os, shutil, random, pickle
import cv2
import keras
from sklearn.metrics import confusion_matrix
from keras import models
from keras import layers
from keras import regularizers
from tensorflow.keras import backend as K
tf.compat.v1.disable_eager_execution()

print("TensorFlow version: " + tf.__version__)
print("Keras version: " + keras.__version__)
print("Detected GPUs: " + str(tf.config.experimental.list_physical_devices('GPU')))
print("Detected CPUs: " + str(tf.config.experimental.list_physical_devices('CPU')))
# Out:
# TensorFlow version: 2.8.1
# Keras version: 2.8.0
# Detected GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Detected CPUs: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# ### Configuration

# %%
train_size = 86980  # number of training images instances
valid_size = 4400  # number of validating images instances
test_size = 12630  # number of test images instances
batch_size = 20  # size of the batch
epochs = 200  # model epochs
img_rows = 32  # height of the input images
img_cols = 32  # width of the input images
output_size = 43  # number of classes (size of the one hot vector)

# %% [markdown]
# ### Load & preprocess data

# %%
home = 'E:\Data\Traffic_Signs_Preprocessed_Class'
models_dir = 'E:\Data\Traffic_Signs_Detection_Models'
model_name = 'tsd_class_v8.h5'
data_dir = "data.pickle"

# %%
# raw data & variables
data = pd.read_pickle(os.path.join(home, data_dir))

x_train = np.flip(np.rot90(data['x_train'].transpose(0, 3, 2, 1), axes=(1, 2)), axis=1)[:train_size].astype('float64')
y_train = keras.utils.np_utils.to_categorical(data['y_train'][:train_size]).astype('float64')

x_test = np.flip(np.rot90(data['x_test'].transpose(0, 3, 2, 1), axes=(1, 2)), axis=1)[:test_size].astype('float64')
y_test = keras.utils.np_utils.to_categorical(data['y_test'][:test_size]).astype('float64')

x_valid = np.flip(np.rot90(data['x_validation'].transpose(0, 3, 2, 1), axes=(1, 2)), axis=1)[:valid_size].astype('float64')
y_valid = keras.utils.np_utils.to_categorical(data['y_validation'][:valid_size]).astype('float64')

labels = data['labels']

# %%
def decode_one_hot(one_hot):
    return np.where(one_hot == 1)[0][0]

# %%
def percentage_one_hot(one_hot):
    return round(one_hot*100, 2)

# %%
def show_class_example(x_data, y_data, labels, c):
    assert len(x_data) == len(y_data)
    
    while True:
        index = random.randint(0, len(y_data))
        if decode_one_hot(y_data[index]) == c:
            f, ax = plt.subplots(1)
            ax.set_title(labels[c])
            ax.imshow(x_data[index])
            break

# %%
def show_sample(shape, x_data, y_data, labels):
    assert shape[0] > 1 and shape[1] >1
    assert len(x_data) == len(y_data)
    
    height = 4*shape[0]
    width = 4*shape[1]
    
    f, ax = plt.subplots(shape[0], shape[1])
    f.set_size_inches(width, height)
    for y in range(shape[0]):
        for x in range(shape[1]):
            index = random.randint(0, len(x_data))
            ax[y][x].set_title(labels[decode_one_hot(y_data[index])])
            ax[y][x].imshow(x_data[index])

# %%
show_sample((7, 7), x_test, y_test, labels)

# %% [markdown]
# ### Model

# %%
model = models.Sequential()

model.add(layers.Conv2D(48, (3, 3), activation=tf.keras.layers.PReLU(), kernel_regularizer=regularizers.L2(l2=2e-4), input_shape=(img_rows, img_cols, 3), padding="valid"))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((3, 3)))
model.add(layers.Dropout(.18))

model.add(layers.Conv2D(32, (3, 3), activation=tf.keras.layers.PReLU(), kernel_regularizer=regularizers.L2(l2=2e-4), padding="valid"))
model.add(layers.BatchNormalization())
model.add(layers.AveragePooling2D((2, 2)))
model.add(layers.Dropout(.18))
model.add(layers.Flatten())

model.add(layers.Dense(43, kernel_regularizer=regularizers.L2(l2=2e-4), activation='selu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(.1))

model.add(layers.Dense(86, kernel_regularizer=regularizers.L2(l2=2e-4), activation='selu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(.1))

model.add(layers.Dense(output_size, activation='sigmoid'))

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.0005, momentum=0.9),
              metrics=['acc'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 30, 30, 48)        44544
#
#  batch_normalization_8 (Batc  (None, 30, 30, 48)       192
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 48)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 10, 10, 48)        0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 32)          15904
#
#  batch_normalization_9 (Batc  (None, 8, 8, 32)         128
#  hNormalization)
#
#  average_pooling2d_2 (Averag  (None, 4, 4, 32)         0
#  ePooling2D)
#
#  dropout_9 (Dropout)         (None, 4, 4, 32)          0
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 43)                22059
#
#  batch_normalization_10 (Bat  (None, 43)               172
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 43)                0
#
#  dense_7 (Dense)             (None, 86)                3784
#
#  batch_normalization_11 (Bat  (None, 86)               344
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 86)                0
#
#  dense_8 (Dense)             (None, 43)                3741
#
# =================================================================
# Total params: 90,868
# Trainable params: 90,450
# Non-trainable params: 418
# _________________________________________________________________

# %%
history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=batch_size, 
    epochs=epochs,
    #steps_per_epoch=train_size/batch_size,
    #callbacks=[
    #    tf.keras.callbacks.EarlyStopping(min_delta=0.1, patience=5)
    #],
    validation_data=(x_valid, y_valid)
)
# Out:
# Train on 86980 samples, validate on 4400 samples
# Epoch 1/200
# 86980/86980 [==============================] - 100s 1ms/sample - loss: 1.7243 - acc: 0.5362 - val_loss: 0.6780 - val_acc: 0.8339
# Epoch 2/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.6407 - acc: 0.8331 - val_loss: 0.3674 - val_acc: 0.9107
# Epoch 3/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.4235 - acc: 0.8924 - val_loss: 0.2527 - val_acc: 0.9373
# Epoch 4/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.3256 - acc: 0.9183 - val_loss: 0.2349 - val_acc: 0.9461
# Epoch 5/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.2766 - acc: 0.9320 - val_loss: 0.2185 - val_acc: 0.9534
# Epoch 6/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.2443 - acc: 0.9411 - val_loss: 0.2007 - val_acc: 0.9573
# Epoch 7/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.2187 - acc: 0.9479 - val_loss: 0.1998 - val_acc: 0.9584
# Epoch 8/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.2014 - acc: 0.9527 - val_loss: 0.1732 - val_acc: 0.9618
# Epoch 9/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.1872 - acc: 0.9564 - val_loss: 0.1692 - val_acc: 0.9657
# Epoch 10/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1743 - acc: 0.9606 - val_loss: 0.1631 - val_acc: 0.9673
# Epoch 11/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1642 - acc: 0.9621 - val_loss: 0.1778 - val_acc: 0.9607
# Epoch 12/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1596 - acc: 0.9640 - val_loss: 0.1762 - val_acc: 0.9609
# Epoch 13/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1512 - acc: 0.9661 - val_loss: 0.1607 - val_acc: 0.9652
# Epoch 14/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1470 - acc: 0.9675 - val_loss: 0.1703 - val_acc: 0.9641
# Epoch 15/200
# 86980/86980 [==============================] - 104s 1ms/sample - loss: 0.1410 - acc: 0.9689 - val_loss: 0.1569 - val_acc: 0.9702
# Epoch 16/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.1360 - acc: 0.9711 - val_loss: 0.1708 - val_acc: 0.9632
# Epoch 17/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1312 - acc: 0.9716 - val_loss: 0.1591 - val_acc: 0.9655
# Epoch 18/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1273 - acc: 0.9718 - val_loss: 0.1588 - val_acc: 0.9664
# Epoch 19/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1240 - acc: 0.9734 - val_loss: 0.1563 - val_acc: 0.9652
# Epoch 20/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.1210 - acc: 0.9744 - val_loss: 0.1529 - val_acc: 0.9666
# Epoch 21/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.1212 - acc: 0.9738 - val_loss: 0.1648 - val_acc: 0.9695
# Epoch 22/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.1190 - acc: 0.9751 - val_loss: 0.1589 - val_acc: 0.9700
# Epoch 23/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1126 - acc: 0.9768 - val_loss: 0.1388 - val_acc: 0.9723
# Epoch 24/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.1099 - acc: 0.9775 - val_loss: 0.1716 - val_acc: 0.9641
# Epoch 25/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1080 - acc: 0.9780 - val_loss: 0.1596 - val_acc: 0.9693
# Epoch 26/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.1092 - acc: 0.9774 - val_loss: 0.1514 - val_acc: 0.9680
# Epoch 27/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.1045 - acc: 0.9787 - val_loss: 0.1804 - val_acc: 0.9659
# Epoch 28/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1029 - acc: 0.9793 - val_loss: 0.1541 - val_acc: 0.9700
# Epoch 29/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.1019 - acc: 0.9788 - val_loss: 0.1446 - val_acc: 0.9727
# Epoch 30/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.1018 - acc: 0.9796 - val_loss: 0.1883 - val_acc: 0.9611
# Epoch 31/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0982 - acc: 0.9799 - val_loss: 0.1810 - val_acc: 0.9652
# Epoch 32/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0968 - acc: 0.9807 - val_loss: 0.1525 - val_acc: 0.9684
# Epoch 33/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0980 - acc: 0.9805 - val_loss: 0.1603 - val_acc: 0.9668
# Epoch 34/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0939 - acc: 0.9812 - val_loss: 0.1573 - val_acc: 0.9689
# Epoch 35/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0951 - acc: 0.9809 - val_loss: 0.1654 - val_acc: 0.9666
# Epoch 36/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0948 - acc: 0.9811 - val_loss: 0.1808 - val_acc: 0.9645
# Epoch 37/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0935 - acc: 0.9812 - val_loss: 0.1707 - val_acc: 0.9705
# Epoch 38/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0914 - acc: 0.9815 - val_loss: 0.1517 - val_acc: 0.9702
# Epoch 39/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0903 - acc: 0.9822 - val_loss: 0.1639 - val_acc: 0.9675
# Epoch 40/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0907 - acc: 0.9819 - val_loss: 0.1483 - val_acc: 0.9714
# Epoch 41/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0889 - acc: 0.9822 - val_loss: 0.1558 - val_acc: 0.9711
# Epoch 42/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0883 - acc: 0.9824 - val_loss: 0.1675 - val_acc: 0.9657
# Epoch 43/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0879 - acc: 0.9828 - val_loss: 0.1758 - val_acc: 0.9648
# Epoch 44/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0876 - acc: 0.9828 - val_loss: 0.1783 - val_acc: 0.9675
# Epoch 45/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0865 - acc: 0.9827 - val_loss: 0.1616 - val_acc: 0.9675
# Epoch 46/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0861 - acc: 0.9831 - val_loss: 0.1593 - val_acc: 0.9723
# Epoch 47/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0830 - acc: 0.9838 - val_loss: 0.1533 - val_acc: 0.9725
# Epoch 48/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0837 - acc: 0.9834 - val_loss: 0.1611 - val_acc: 0.9684
# Epoch 49/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0816 - acc: 0.9847 - val_loss: 0.1526 - val_acc: 0.9739
# Epoch 50/200
# 86980/86980 [==============================] - 104s 1ms/sample - loss: 0.0855 - acc: 0.9832 - val_loss: 0.1616 - val_acc: 0.9720
# Epoch 51/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0816 - acc: 0.9838 - val_loss: 0.1702 - val_acc: 0.9693
# Epoch 52/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0812 - acc: 0.9836 - val_loss: 0.1422 - val_acc: 0.9707
# Epoch 53/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0802 - acc: 0.9843 - val_loss: 0.1430 - val_acc: 0.9723
# Epoch 54/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0784 - acc: 0.9851 - val_loss: 0.1441 - val_acc: 0.9714
# Epoch 55/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0781 - acc: 0.9855 - val_loss: 0.1602 - val_acc: 0.9714
# Epoch 56/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0785 - acc: 0.9850 - val_loss: 0.1482 - val_acc: 0.9730
# Epoch 57/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0782 - acc: 0.9846 - val_loss: 0.1705 - val_acc: 0.9691
# Epoch 58/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0774 - acc: 0.9849 - val_loss: 0.1598 - val_acc: 0.9670
# Epoch 59/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0771 - acc: 0.9848 - val_loss: 0.1691 - val_acc: 0.9716
# Epoch 60/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0775 - acc: 0.9849 - val_loss: 0.1576 - val_acc: 0.9725
# Epoch 61/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0789 - acc: 0.9848 - val_loss: 0.1517 - val_acc: 0.9698
# Epoch 62/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0783 - acc: 0.9847 - val_loss: 0.1836 - val_acc: 0.9716
# Epoch 63/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0760 - acc: 0.9853 - val_loss: 0.1715 - val_acc: 0.9709
# Epoch 64/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0745 - acc: 0.9852 - val_loss: 0.1477 - val_acc: 0.9730
# Epoch 65/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0760 - acc: 0.9853 - val_loss: 0.1606 - val_acc: 0.9691
# Epoch 66/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0748 - acc: 0.9856 - val_loss: 0.1503 - val_acc: 0.9720
# Epoch 67/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0736 - acc: 0.9858 - val_loss: 0.1464 - val_acc: 0.9727
# Epoch 68/200
# 86980/86980 [==============================] - 103s 1ms/sample - loss: 0.0764 - acc: 0.9852 - val_loss: 0.1798 - val_acc: 0.9664
# Epoch 69/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0737 - acc: 0.9860 - val_loss: 0.1678 - val_acc: 0.9650
# Epoch 70/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0756 - acc: 0.9852 - val_loss: 0.1511 - val_acc: 0.9730
# Epoch 71/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0735 - acc: 0.9858 - val_loss: 0.1684 - val_acc: 0.9693
# Epoch 72/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0705 - acc: 0.9864 - val_loss: 0.1805 - val_acc: 0.9659
# Epoch 73/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0719 - acc: 0.9856 - val_loss: 0.1616 - val_acc: 0.9700
# Epoch 74/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0714 - acc: 0.9865 - val_loss: 0.1716 - val_acc: 0.9707
# Epoch 75/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0718 - acc: 0.9863 - val_loss: 0.1619 - val_acc: 0.9659
# Epoch 76/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0705 - acc: 0.9868 - val_loss: 0.1569 - val_acc: 0.9734
# Epoch 77/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0717 - acc: 0.9862 - val_loss: 0.1585 - val_acc: 0.9682
# Epoch 78/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0696 - acc: 0.9870 - val_loss: 0.1609 - val_acc: 0.9709
# Epoch 79/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0682 - acc: 0.9871 - val_loss: 0.1515 - val_acc: 0.9718
# Epoch 80/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0700 - acc: 0.9867 - val_loss: 0.1653 - val_acc: 0.9732
# Epoch 81/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0724 - acc: 0.9857 - val_loss: 0.1639 - val_acc: 0.9698
# Epoch 82/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0698 - acc: 0.9867 - val_loss: 0.1760 - val_acc: 0.9680
# Epoch 83/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0703 - acc: 0.9863 - val_loss: 0.1788 - val_acc: 0.9675
# Epoch 84/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0712 - acc: 0.9859 - val_loss: 0.1571 - val_acc: 0.9752
# Epoch 85/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0695 - acc: 0.9864 - val_loss: 0.1692 - val_acc: 0.9702
# Epoch 86/200
# 86980/86980 [==============================] - 103s 1ms/sample - loss: 0.0703 - acc: 0.9862 - val_loss: 0.1773 - val_acc: 0.9736
# Epoch 87/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0687 - acc: 0.9866 - val_loss: 0.1637 - val_acc: 0.9732
# Epoch 88/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0713 - acc: 0.9860 - val_loss: 0.1750 - val_acc: 0.9743
# Epoch 89/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0680 - acc: 0.9870 - val_loss: 0.1581 - val_acc: 0.9741
# Epoch 90/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0679 - acc: 0.9868 - val_loss: 0.1925 - val_acc: 0.9684
# Epoch 91/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0650 - acc: 0.9874 - val_loss: 0.1539 - val_acc: 0.9734
# Epoch 92/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0671 - acc: 0.9872 - val_loss: 0.1720 - val_acc: 0.9675
# Epoch 93/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0684 - acc: 0.9865 - val_loss: 0.1592 - val_acc: 0.9725
# Epoch 94/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0675 - acc: 0.9870 - val_loss: 0.1545 - val_acc: 0.9755
# Epoch 95/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0667 - acc: 0.9870 - val_loss: 0.1681 - val_acc: 0.9709
# Epoch 96/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0698 - acc: 0.9867 - val_loss: 0.1548 - val_acc: 0.9766
# Epoch 97/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0683 - acc: 0.9867 - val_loss: 0.1559 - val_acc: 0.9730
# Epoch 98/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0683 - acc: 0.9864 - val_loss: 0.1571 - val_acc: 0.9725
# Epoch 99/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0663 - acc: 0.9874 - val_loss: 0.1572 - val_acc: 0.9709
# Epoch 100/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0637 - acc: 0.9881 - val_loss: 0.1472 - val_acc: 0.9764
# Epoch 101/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0661 - acc: 0.9877 - val_loss: 0.2021 - val_acc: 0.9625
# Epoch 102/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0656 - acc: 0.9874 - val_loss: 0.1752 - val_acc: 0.9700
# Epoch 103/200
# 86980/86980 [==============================] - 103s 1ms/sample - loss: 0.0652 - acc: 0.9876 - val_loss: 0.1647 - val_acc: 0.9741
# Epoch 104/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0657 - acc: 0.9875 - val_loss: 0.1491 - val_acc: 0.9698
# Epoch 105/200
# 86980/86980 [==============================] - 103s 1ms/sample - loss: 0.0649 - acc: 0.9876 - val_loss: 0.1532 - val_acc: 0.9752
# Epoch 106/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0673 - acc: 0.9870 - val_loss: 0.1538 - val_acc: 0.9718
# Epoch 107/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0649 - acc: 0.9876 - val_loss: 0.1479 - val_acc: 0.9739
# Epoch 108/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0651 - acc: 0.9874 - val_loss: 0.1674 - val_acc: 0.9702
# Epoch 109/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0673 - acc: 0.9870 - val_loss: 0.1602 - val_acc: 0.9723
# Epoch 110/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0664 - acc: 0.9874 - val_loss: 0.1554 - val_acc: 0.9727
# Epoch 111/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0639 - acc: 0.9877 - val_loss: 0.1537 - val_acc: 0.9709
# Epoch 112/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0668 - acc: 0.9872 - val_loss: 0.1566 - val_acc: 0.9752
# Epoch 113/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0637 - acc: 0.9879 - val_loss: 0.1629 - val_acc: 0.9727
# Epoch 114/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0637 - acc: 0.9879 - val_loss: 0.1579 - val_acc: 0.9707
# Epoch 115/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0639 - acc: 0.9878 - val_loss: 0.1512 - val_acc: 0.9741
# Epoch 116/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0635 - acc: 0.9877 - val_loss: 0.1472 - val_acc: 0.9748
# Epoch 117/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0644 - acc: 0.9878 - val_loss: 0.1783 - val_acc: 0.9686
# Epoch 118/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0632 - acc: 0.9882 - val_loss: 0.1666 - val_acc: 0.9734
# Epoch 119/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0640 - acc: 0.9879 - val_loss: 0.1730 - val_acc: 0.9727
# Epoch 120/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0645 - acc: 0.9875 - val_loss: 0.1865 - val_acc: 0.9600
# Epoch 121/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0657 - acc: 0.9872 - val_loss: 0.1374 - val_acc: 0.9782
# Epoch 122/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0650 - acc: 0.9873 - val_loss: 0.1465 - val_acc: 0.9739
# Epoch 123/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0639 - acc: 0.9876 - val_loss: 0.1446 - val_acc: 0.9757
# Epoch 124/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0624 - acc: 0.9885 - val_loss: 0.1548 - val_acc: 0.9725
# Epoch 125/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0624 - acc: 0.9880 - val_loss: 0.1507 - val_acc: 0.9752
# Epoch 126/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0631 - acc: 0.9880 - val_loss: 0.1498 - val_acc: 0.9700
# Epoch 127/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0639 - acc: 0.9880 - val_loss: 0.1571 - val_acc: 0.9745
# Epoch 128/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0633 - acc: 0.9879 - val_loss: 0.1555 - val_acc: 0.9736
# Epoch 129/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0616 - acc: 0.9883 - val_loss: 0.1381 - val_acc: 0.9757
# Epoch 130/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0624 - acc: 0.9883 - val_loss: 0.1461 - val_acc: 0.9732
# Epoch 131/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0629 - acc: 0.9883 - val_loss: 0.1641 - val_acc: 0.9682
# Epoch 132/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0634 - acc: 0.9880 - val_loss: 0.1993 - val_acc: 0.9632
# Epoch 133/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0622 - acc: 0.9885 - val_loss: 0.1468 - val_acc: 0.9761
# Epoch 134/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0643 - acc: 0.9875 - val_loss: 0.1585 - val_acc: 0.9680
# Epoch 135/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0633 - acc: 0.9877 - val_loss: 0.1666 - val_acc: 0.9652
# Epoch 136/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0625 - acc: 0.9879 - val_loss: 0.1506 - val_acc: 0.9720
# Epoch 137/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0634 - acc: 0.9881 - val_loss: 0.1397 - val_acc: 0.9739
# Epoch 138/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0644 - acc: 0.9873 - val_loss: 0.1617 - val_acc: 0.9725
# Epoch 139/200
# 86980/86980 [==============================] - 103s 1ms/sample - loss: 0.0629 - acc: 0.9878 - val_loss: 0.1527 - val_acc: 0.9723
# Epoch 140/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0619 - acc: 0.9879 - val_loss: 0.1591 - val_acc: 0.9732
# Epoch 141/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0634 - acc: 0.9880 - val_loss: 0.1332 - val_acc: 0.9757
# Epoch 142/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0625 - acc: 0.9878 - val_loss: 0.1590 - val_acc: 0.9730
# Epoch 143/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0631 - acc: 0.9875 - val_loss: 0.1581 - val_acc: 0.9725
# Epoch 144/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0612 - acc: 0.9882 - val_loss: 0.1578 - val_acc: 0.9709
# Epoch 145/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0616 - acc: 0.9881 - val_loss: 0.1453 - val_acc: 0.9732
# Epoch 146/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0613 - acc: 0.9885 - val_loss: 0.1641 - val_acc: 0.9705
# Epoch 147/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0607 - acc: 0.9886 - val_loss: 0.1594 - val_acc: 0.9695
# Epoch 148/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0603 - acc: 0.9887 - val_loss: 0.1708 - val_acc: 0.9720
# Epoch 149/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0602 - acc: 0.9888 - val_loss: 0.1367 - val_acc: 0.9759
# Epoch 150/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0613 - acc: 0.9882 - val_loss: 0.1742 - val_acc: 0.9620
# Epoch 151/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0620 - acc: 0.9885 - val_loss: 0.1765 - val_acc: 0.9675
# Epoch 152/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0623 - acc: 0.9887 - val_loss: 0.1605 - val_acc: 0.9723
# Epoch 153/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0607 - acc: 0.9888 - val_loss: 0.1595 - val_acc: 0.9707
# Epoch 154/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0633 - acc: 0.9878 - val_loss: 0.1687 - val_acc: 0.9680
# Epoch 155/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0615 - acc: 0.9881 - val_loss: 0.1589 - val_acc: 0.9741
# Epoch 156/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0614 - acc: 0.9883 - val_loss: 0.1503 - val_acc: 0.9759
# Epoch 157/200
# 86980/86980 [==============================] - 105s 1ms/sample - loss: 0.0616 - acc: 0.9882 - val_loss: 0.1583 - val_acc: 0.9755
# Epoch 158/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0623 - acc: 0.9881 - val_loss: 0.1565 - val_acc: 0.9686
# Epoch 159/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0603 - acc: 0.9889 - val_loss: 0.1581 - val_acc: 0.9734
# Epoch 160/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0620 - acc: 0.9882 - val_loss: 0.1643 - val_acc: 0.9755
# Epoch 161/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0608 - acc: 0.9884 - val_loss: 0.1474 - val_acc: 0.9761
# Epoch 162/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0609 - acc: 0.9888 - val_loss: 0.1610 - val_acc: 0.9723
# Epoch 163/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0603 - acc: 0.9886 - val_loss: 0.1232 - val_acc: 0.9789
# Epoch 164/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0591 - acc: 0.9890 - val_loss: 0.1742 - val_acc: 0.9730
# Epoch 165/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0618 - acc: 0.9881 - val_loss: 0.1564 - val_acc: 0.9759
# Epoch 166/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0616 - acc: 0.9883 - val_loss: 0.1376 - val_acc: 0.9773
# Epoch 167/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0600 - acc: 0.9888 - val_loss: 0.1755 - val_acc: 0.9709
# Epoch 168/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0600 - acc: 0.9885 - val_loss: 0.1525 - val_acc: 0.9755
# Epoch 169/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0605 - acc: 0.9886 - val_loss: 0.1363 - val_acc: 0.9782
# Epoch 170/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0618 - acc: 0.9881 - val_loss: 0.1444 - val_acc: 0.9750
# Epoch 171/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0623 - acc: 0.9877 - val_loss: 0.1376 - val_acc: 0.9752
# Epoch 172/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0618 - acc: 0.9883 - val_loss: 0.1499 - val_acc: 0.9748
# Epoch 173/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0590 - acc: 0.9887 - val_loss: 0.1295 - val_acc: 0.9780
# Epoch 174/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0604 - acc: 0.9886 - val_loss: 0.1633 - val_acc: 0.9695
# Epoch 175/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0583 - acc: 0.9892 - val_loss: 0.1356 - val_acc: 0.9780
# Epoch 176/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0598 - acc: 0.9888 - val_loss: 0.1345 - val_acc: 0.9752
# Epoch 177/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0590 - acc: 0.9887 - val_loss: 0.1291 - val_acc: 0.9775
# Epoch 178/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0588 - acc: 0.9890 - val_loss: 0.1677 - val_acc: 0.9695
# Epoch 179/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0602 - acc: 0.9889 - val_loss: 0.1516 - val_acc: 0.9718
# Epoch 180/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0609 - acc: 0.9885 - val_loss: 0.1311 - val_acc: 0.9782
# Epoch 181/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0608 - acc: 0.9884 - val_loss: 0.1470 - val_acc: 0.9743
# Epoch 182/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0590 - acc: 0.9889 - val_loss: 0.1317 - val_acc: 0.9786
# Epoch 183/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0599 - acc: 0.9884 - val_loss: 0.1402 - val_acc: 0.9732
# Epoch 184/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0609 - acc: 0.9885 - val_loss: 0.1443 - val_acc: 0.9730
# Epoch 185/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0590 - acc: 0.9892 - val_loss: 0.1389 - val_acc: 0.9795
# Epoch 186/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0590 - acc: 0.9887 - val_loss: 0.1381 - val_acc: 0.9732
# Epoch 187/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0618 - acc: 0.9887 - val_loss: 0.1371 - val_acc: 0.9741
# Epoch 188/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0607 - acc: 0.9888 - val_loss: 0.1539 - val_acc: 0.9709
# Epoch 189/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0588 - acc: 0.9890 - val_loss: 0.1230 - val_acc: 0.9755
# Epoch 190/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0591 - acc: 0.9890 - val_loss: 0.1705 - val_acc: 0.9711
# Epoch 191/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0586 - acc: 0.9890 - val_loss: 0.1459 - val_acc: 0.9752
# Epoch 192/200
# 86980/86980 [==============================] - 103s 1ms/sample - loss: 0.0602 - acc: 0.9888 - val_loss: 0.1647 - val_acc: 0.9700
# Epoch 193/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0600 - acc: 0.9885 - val_loss: 0.1729 - val_acc: 0.9700
# Epoch 194/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0600 - acc: 0.9890 - val_loss: 0.1542 - val_acc: 0.9698
# Epoch 195/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0590 - acc: 0.9889 - val_loss: 0.1406 - val_acc: 0.9761
# Epoch 196/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0609 - acc: 0.9889 - val_loss: 0.1509 - val_acc: 0.9750
# Epoch 197/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0604 - acc: 0.9887 - val_loss: 0.1572 - val_acc: 0.9761
# Epoch 198/200
# 86980/86980 [==============================] - 102s 1ms/sample - loss: 0.0592 - acc: 0.9893 - val_loss: 0.1569 - val_acc: 0.9745
# Epoch 199/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0605 - acc: 0.9887 - val_loss: 0.1662 - val_acc: 0.9736
# Epoch 200/200
# 86980/86980 [==============================] - 101s 1ms/sample - loss: 0.0597 - acc: 0.9889 - val_loss: 0.1433 - val_acc: 0.9773

# %%
model.save(os.path.join(models_dir, model_name))

# %%
model = keras.models.load_model(os.path.join(models_dir, model_name))

# %% [markdown]
# ### Results

# %%
def plot_comparison(value, val_value, metric):
    plt.clf()
    plt.figure(figsize=(25,5))
    epochs = range(len(value))
    plt.plot(epochs, value, 'bo', label=f"Training {metric}")
    plt.plot(epochs, val_value, 'b', label=f"Validation {metric}")
    plt.title(f"Comparison of Training and Validation {metric}")
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# %%
def print_evaluation(model, x_test, y_test):
    loss, acc = model.evaluate(x_test, y_test, batch_size=batch_size, verbose=0)
    print(f"Test accuracy: {round(acc * 100, 2)}%")
    print(f"Test loss: {round(loss, 2)}")

# %%
def print_confusion_matrix(model, x_test, y_test, labels):
    y_pred = model.predict(x_test, verbose=0, batch_size=batch_size)
    y_pred = np.argmax(y_pred, axis=1)
    y_test = np.argmax(y_test, axis=1)
    
    cm = confusion_matrix(y_test, y_pred)
    ticks=np.linspace(0, output_size, num=output_size+1)
    plt.clf()
    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='none')
    plt.colorbar()
    plt.xticks(ticks, fontsize=6)
    plt.xlabel("Predicted")
    plt.yticks(ticks, fontsize=6)
    plt.ylabel("True")
    plt.grid(True)
    plt.show()

# %%
print_evaluation(model, x_test, y_test)
# Out:
# Test accuracy: 96.29%
# Test loss: 0.18

# %%
print_confusion_matrix(model, x_test, y_test, labels)
# Out:
# c:\programy\python39\lib\site-packages\keras\engine\training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
plot_comparison(history.history['acc'], history.history['val_acc'], "acc")

# %%
plot_comparison(history.history['loss'], history.history['val_loss'], "loss")

# %% [markdown]
# ### Visualizing activation layers

# %%
def visualize_layers(model, img):
    layer_outputs = [layer.output for layer in model.layers if len(layer.output_shape) > 2 and "dropout" not in layer.name]
    activation_model = models.Model(inputs=model.input, outputs=layer_outputs)
    activations = activation_model.predict(img.reshape((1, img_rows, img_cols, 3)), verbose=0)

    layer_names = []
    images_per_row = 16
    for layer in layer_outputs:
        layer_names.append(layer.name)
        try:
            if layer.filters < images_per_row:
                images_per_row = layer.filters
        except:
            pass
        
    plt.figure(figsize=(1, 1))
    plt.title("Input image", fontsize=10)
    plt.imshow(img)

    for layer_name, layer_activation in zip(layer_names, activations):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, size * images_per_row))

        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0, :, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                if channel_image.std() != 0:
                    channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size, row * size : (row + 1) * size] = channel_image

        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')

    plt.show()

# %%
visualize_layers(model, x_test[1])
# Out:
# c:\programy\python39\lib\site-packages\keras\engine\training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
visualize_layers(model, x_test[140])

# %%
visualize_layers(model, x_test[5138])

# %% [markdown]
# ### Visualizing filters

# %%
def deprocess_image(x):
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    x += 0.5
    x = np.clip(x, 0, 1)

    x *= 255
    x = np.clip(x, 0, 255).astype('uint8')
    
    return x

# %%
def generate_pattern(model, layer_name, filter_index, size=150):
    layer_output = model.get_layer(layer_name).output
    loss = K.mean(layer_output[:, :, :, filter_index])

    grads = K.gradients(loss, model.input)[0]
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)
    iterate = K.function([model.input], [loss, grads])
    
    input_img_data = np.random.random((1, size, size, 3)) * 10 + 128.

    step = 1.
    for i in range(40):
        loss_value, grads_value = iterate([input_img_data])
        input_img_data += grads_value * step
        
    img = input_img_data[0]
    return deprocess_image(img)

# %%
def rows_cols(value):
    assert value >= 1
    
    rows = 1
    cols = value
    for i in range(2, value//2+1):
        if value % i == 0:
            if np.abs(i - int(value / i)) < np.abs(rows - cols):
                rows = i
                cols = int(value / i)
    
    return rows, cols

# %%
def visualize_filters(model):
    margin = 3
    size = 32
    layers = [layer.name for layer in model.layers if len(layer.output_shape) > 2 and "conv" in layer.name]
    for layer_name in layers: 
        f_count = model.get_layer(layer_name).filters
        rows, cols = rows_cols(f_count)

        results = np.zeros((rows * size + (rows-1) * margin, cols * size + (cols-1) * margin, 3), dtype=np.uint8)
        for i in range(rows):
            for j in range(cols):
                filter_img = generate_pattern(model, layer_name, j + (i * cols), size=size)
                horizontal_start = i * size + i * margin
                horizontal_end = horizontal_start + size
                vertical_start = j * size + j * margin
                vertical_end = vertical_start + size
                results[horizontal_start : horizontal_end, vertical_start : vertical_end, : ] = filter_img

        print("Layer name: " + layer_name)
        plt.figure(figsize=(size / 2, size / 2))
        plt.imshow(results)
        plt.show()

# %%
visualize_filters(model)
# Out:
# Layer name: conv2d_4
# Layer name: conv2d_5
